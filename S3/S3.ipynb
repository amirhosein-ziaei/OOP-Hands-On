# %% [markdown]
# ---
# # Session Three
# ---

# %% [markdown]
# **Instance methods, Static methods and Class methods**

# %%
from datetime import date
class person:
    def __init__(self, first, age) :
        self.name = first
        self.age = age
    
    @classmethod
    def my_classmethod(cls, name, birthdate) :
        return cls(name, date.today().year - birthdate)
    @staticmethod
    def is_adult(my_age) :
        return my_age > 18    

person1 = person("Amirhosein", 27)
print(person1.name, person1.age)

person2 = person.my_classmethod("Amirhosein", 1993)
print(person2.name, person2.age)

print(person1.is_adult(27))

# %%
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)
        
emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)

Employee.pay_rising = 0.6   

print(Employee.pay_rising)
print(emp1.pay_rising)
print(emp2.pay_rising)

# %%
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)
        
        
emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)

emp1.__class__.pay_rising = 0.8  

print(Employee.pay_rising)
print(emp1.pay_rising)
print(emp2.pay_rising)

# %%
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)

    @classmethod
    def set_raise_amount(cls, amnt) :
        cls.pay_rising = amnt

emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)

Employee.set_raise_amount(0.45) 

print(Employee.pay_rising)
print(emp1.pay_rising)
print(emp2.pay_rising)

# %%
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)

    @classmethod
    def set_raise_amount(cls, amnt) :
        cls.pay_rising = amnt
          
        
emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)

emp1.set_raise_amount(0.2) 

print(Employee.pay_rising)
print(emp1.pay_rising)
print(emp2.pay_rising)

# %%
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)

    @classmethod
    def set_raise_amount(cls, amnt) :
        cls.pay_rising = amnt
          
        
emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)
emp3_str = "Amirhosein-Ziaei-5000"
emp4_str = "Reza-Irani-3000"
emp5_str = "Zahra-Irani-1000"
first3, last3, pay3 = emp3_str.split("-")
first4, last4, pay4 = emp4_str.split("-")
first5, last5, pay5 = emp5_str.split("-")

new_emp3 = Employee(first3, last3, pay3)
new_emp4 = Employee(first4, last4, pay4)
new_emp5 = Employee(first5, last5, pay5)

print(new_emp3.first)
print(new_emp4.last)
print(new_emp5.mail)

# %%
import datetime
class Employee:
    pay_rising = 0.1    
    def __init__(self, first, last, pay): 
        self.first = first
        self.last = last
        self.pay = pay
        self.mail = first + "." + last + "@company.com"
    def fullname(self):
        return "{} {}".format(self.first,self.last)
    def pay_increase(self):
        self.pay += int(self.pay * self.pay_rising)
    
    @classmethod
    def set_raise_amount(cls, amnt) :
        cls.pay_rising = amnt

    @classmethod
    def from_str_emp(cls, emp_str) :
        first, last, pay = emp_str.split("-")
        return Employee(first, last, pay)
        # or return cls(first, last, pay)

    @staticmethod
    def is_workday(day) :
        if day.weekday() == 3 or day.weekday() == 4:
            return False
        else:
            return True 
        

emp1 = Employee("Amirhosein", "Ziaei", 2000) 
emp2 = Employee("Ali", "Karimi", 2500)
emp3_str = "Amirhosein-Ziaei-5000"
emp4_str = "Reza-Irani-3000"
emp5_str = "Zahra-Irani-1000"

new_emp3 = Employee.from_str_emp(emp3_str)
new_emp4 = Employee.from_str_emp(emp4_str)
new_emp5 = Employee.from_str_emp(emp5_str)
my_date = datetime.date(2020,2,10)

print(Employee.is_workday(my_date))
print(new_emp3.first)
print(new_emp4.last)
print(new_emp5.mail)
